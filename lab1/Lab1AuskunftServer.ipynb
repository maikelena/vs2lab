# %% [markdown]
# # Telefonauskunft – Server
#
# Dieses Notebook startet den Auskunftsserver.
#
# Vorgehen:
# 1. `clientserver` importieren
# 2. Server-Objekt erzeugen
# 3. `server.serve()` ausführen
#
# Solange der Server läuft, wartet er auf Anfragen vom Client.
# Zum Beenden kann die laufende Zelle mit **Kernel Interrupt** oder **Stop** abgebrochen werden.

# %%
import clientserver 
server = clientserver.Server()
# Out:
# 2026-04-15 17:49:55,770 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=67, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>

# %% [markdown]
# ## Server starten
#
# Die folgende Zelle startet den Server und blockiert dann, weil der Server auf Client-Verbindungen wartet.

# %%
server.serve()
# Out:
# 2026-04-15 17:50:00,147 - vs2lab.lab1.clientserver.Server - INFO - Server listening on 127.0.0.1:50007
# 2026-04-15 17:50:05,399 - vs2lab.lab1.clientserver.Server - INFO - Accepted connection from ('127.0.0.1', 42892)
# 2026-04-15 17:50:08,425 - vs2lab.lab1.clientserver.Server - INFO - Received request: GET|Alice
# 2026-04-15 17:50:08,428 - vs2lab.lab1.clientserver.Server - INFO - Sending response: OK|Alice|12345
# 2026-04-15 17:50:11,396 - vs2lab.lab1.clientserver.Server - INFO - Received request: GET|Unknown
# 2026-04-15 17:50:11,399 - vs2lab.lab1.clientserver.Server - INFO - Sending response: ERROR|NOTFOUND
# 2026-04-15 17:50:14,198 - vs2lab.lab1.clientserver.Server - INFO - Received request: GETALL
# 2026-04-15 17:50:14,212 - vs2lab.lab1.clientserver.Server - INFO - Sending response: OKALL|Alice:12345;Bob:67890;Charlie:55555;David:54321;Eve:98765;Frank:11111
# 2026-04-15 17:50:17,551 - vs2lab.lab1.clientserver.Server - INFO - Client closed connection
