# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import telefonauskunft

server = telefonauskunft.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import telefonauskunft
#       2
# ----> 3 server = telefonauskunft.Server() # Create a server instance
#       4
#       5 server.serve() # start server routine in the forked process
#
# File /workspaces/vs2lab/lab1/telefonauskunft.py:25, in Server.__init__(self)
#      23 self.sock.bind((const_cs.HOST, const_cs.PORT))
#      24 self.sock.settimeout(3)  # time out in order not to block forever
# ---> 25 self.phonebook = phonebook or {
#      26     "Chloe": "111",
#      27     "Maike": "222",
#      28     "Romy": "333"
#      29 }
#      30 self._logger.info("Server bound to socket " + str(self.sock))
#
# NameError: name 'phonebook' is not defined

# %% [markdown]
# Finished
