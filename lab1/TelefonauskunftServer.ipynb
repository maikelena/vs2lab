# %% [markdown]
# # Telefonauskunft Server Part
# Notebook zum Server der Telefonauskunft.
#
# Schritt 1: telefonauskunft importieren und Server-Objekt erzeugen

# %%
import telefonauskunft
server = telefonauskunft.Server()
# Out:
# 2026-04-13 20:25:15,347 - vs2lab.lab1.clientserver.Server - INFO - Server connected to socket <socket.socket fd=81, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>

# %% [markdown]
# Schritt 2: Server starten. Wartet danach auf Verbindung zu Client.

# %%
server.serve()
# Out:
# 2026-04-13 20:25:15,375 - vs2lab.lab1.clientserver.Server - INFO - Server listening on 127.0.0.1:50007
# 2026-04-13 20:25:22,551 - vs2lab.lab1.clientserver.Server - INFO - Received request: GET|Chloe
# 2026-04-13 20:25:22,560 - vs2lab.lab1.clientserver.Server - INFO - Server received request: GET|Chloe
# 2026-04-13 20:25:22,567 - vs2lab.lab1.clientserver.Server - INFO - Server sent response: OK|Chloe|111
# 2026-04-13 20:25:22,720 - vs2lab.lab1.clientserver.Server - INFO - Received request: GET|Unknown
# 2026-04-13 20:25:22,724 - vs2lab.lab1.clientserver.Server - INFO - Server received request: GET|Unknown
# 2026-04-13 20:25:22,729 - vs2lab.lab1.clientserver.Server - INFO - Server sent response: ERROR|NOTFOUND
# 2026-04-13 20:25:22,779 - vs2lab.lab1.clientserver.Server - INFO - Received request: GETALL
# 2026-04-13 20:25:22,783 - vs2lab.lab1.clientserver.Server - INFO - Server received request: GETALL
# ...

# %% [markdown]
# Finished
